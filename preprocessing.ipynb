# %% [markdown]
# ### Reading Data

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/Maharastra_Election.csv")
df
# Out:
# <ipython-input-4-85385580d42a>:1: DtypeWarning: Columns (13,18,19,38,39,40,41,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/Maharastra_Election.csv")
#         State_Name  Assembly_No  Constituency_No  Year  month  DelimID  \
# 0      Maharashtra           13                1  2019   10.0        4
# 1      Maharashtra           13                1  2019   10.0        4
# 2      Maharashtra           13                1  2019   10.0        4
# 3      Maharashtra           13                1  2019   10.0        4
# 4      Maharashtra           13                1  2019   10.0        4
# ...            ...          ...              ...   ...    ...      ...
# 34376  Maharashtra            1              218  1965    NaN        1
# 34377  Maharashtra            1              218  1965    NaN        1
# 34378  Maharashtra            1              218  1965    NaN        1
# 34379  Maharashtra            1              218  1965    NaN        1
# 34380  Maharashtra            1              218  1965    NaN        1
#
#        Poll_No  Position                      Candidate  Sex  ... No_Terms  \
# 0            0         1              ADV. K. C. PADAVI    M  ...      6.0
# 1            0         2           AAMSHYA FULJI PADAVI    M  ...      0.0
# 2            0         3        NAGESH DILVARSING PADVI    M  ...      0.0
# 3            0         4                           NOTA  NaN  ...      NaN
# 4            0         5  ADV. KAILAS PRATAPSING VASAVE    M  ...      0.0
# ...        ...       ...                            ...  ...  ...      ...
# 34376        1         1                      J.B.DHOTE  NaN  ...      2.0
# 34377        1         2                      N.V.TATAD  NaN  ...      0.0
# 34378        1         3                       B.G.UIKE  NaN  ...      0.0
# 34379        1         4                    M.P.MALUNDE  NaN  ...      0.0
# 34380        1         5                      R.S.GEDAM  NaN  ...      0.0
#
#        Turncoat  Incumbent Recontest  MyNeta_education  \
# 0         False       True      True     Post Graduate
# 1         False      False      True         12th Pass
# 2         False      False      True         12th Pass
# 3           NaN        NaN       NaN               NaN
# 4         False      False     False     Post Graduate
# ...         ...        ...       ...               ...
# 34376     False       True      True               NaN
# 34377     False      False     False               NaN
# 34378     False      False     False               NaN
# 34379     False      False     False               NaN
# 34380     False      False     False               NaN
#
#                            TCPD_Prof_Main TCPD_Prof_Main_Desc  \
# 0                             Agriculture                 NaN
# 1                                   Other                 NaN
# 2                             Agriculture                 NaN
# 3                                     NaN                 NaN
# 4      Liberal Profession or Professional              Lawyer
# ...                                   ...                 ...
# 34376                                 NaN                 NaN
# 34377                                 NaN                 NaN
# 34378                                 NaN                 NaN
# 34379                                 NaN                 NaN
# 34380                                 NaN                 NaN
#
#       TCPD_Prof_Second TCPD_Prof_Second_Desc                 Election_Type
# 0                  NaN                   NaN  State Assembly Election (AE)
# 1                  NaN                   NaN  State Assembly Election (AE)
# 2                  NaN                   NaN  State Assembly Election (AE)
# 3                  NaN                   NaN  State Assembly Election (AE)
# 4                  NaN                   NaN  State Assembly Election (AE)
# ...                ...                   ...                           ...
# 34376              NaN                   NaN  State Assembly Election (AE)
# 34377              NaN                   NaN  State Assembly Election (AE)
# 34378              NaN                   NaN  State Assembly Election (AE)
# 34379              NaN                   NaN  State Assembly Election (AE)
# 34380              NaN                   NaN  State Assembly Election (AE)
#
# [34381 rows x 47 columns]

# %%
print("Total rows:", len(df))
# Out:
# Total rows: 34381

# %% [markdown]
# ### Dropping Columns

# %%
dropcol=['State_Name','Assembly_No','month','District_Name','Sub_Region','DelimID','Poll_No','N_Cand','Deposit_Lost','ENOP','pid','Party_Type_TCPD','Party_ID','last_poll',
         'Contested','Last_Party','Last_Party_ID','Last_Constituency_Name','Candidate','Same_Constituency','Same_Party','No_Terms','Turncoat',
         'Turnout_Percentage','Recontest','MyNeta_education','TCPD_Prof_Main','TCPD_Prof_Main_Desc','TCPD_Prof_Second','TCPD_Prof_Second_Desc',
         'Election_Type','Electors','Valid_Votes']
df1 = df.drop(dropcol, axis=1)
df1.head()
# Out:
#    Constituency_No  Year  Position  Sex Party  Votes   Age Candidate_Type  \
# 0                1  2019         1    M   INC  82770  61.0             ST
# 1                1  2019         2    M   SHS  80674  51.0             ST
# 2                1  2019         3    M   IND  21664  44.0             ST
# 3                1  2019         4  NaN  NOTA   4857   NaN            NaN
# 4                1  2019         5    M  AAAP   4055  28.0             ST
#
#   Constituency_Name Constituency_Type  Vote_Share_Percentage  Margin  \
# 0         AKKALKUWA                ST                  41.26    2096
# 1         AKKALKUWA                ST                  40.21   59010
# 2         AKKALKUWA                ST                  10.80   16807
# 3         AKKALKUWA                ST                   2.42     802
# 4         AKKALKUWA                ST                   2.02     271
#
#    Margin_Percentage Incumbent
# 0               1.04      True
# 1              29.41     False
# 2               8.38     False
# 3               0.40       NaN
# 4               0.14     False

# %%
df1.shape
# Out:
# (34381, 14)

# %% [markdown]
# ### Removing rows where postion is greater than 3

# %%
df2 = df1[df1.Position <= 3].copy()
df2
#creates a copy of the dataframe where positions are lesser or equal to 3
#After removing rows where the position is greater than 3, we are left with 11,172 rows.
# Out:
#        Constituency_No  Year  Position  Sex Party  Votes   Age Candidate_Type  \
# 0                    1  2019         1    M   INC  82770  61.0             ST
# 1                    1  2019         2    M   SHS  80674  51.0             ST
# 2                    1  2019         3    M   IND  21664  44.0             ST
# 7                    2  2019         1    M   BJP  94931  50.0             ST
# 8                    2  2019         2    M   INC  86940  51.0             ST
# ...                ...   ...       ...  ...   ...    ...   ...            ...
# 34374              190  1965         2  NaN   REP  20251   NaN            NaN
# 34375              190  1965         3  NaN   IND    266   NaN            NaN
# 34376              218  1965         1  NaN   IND  25609   NaN            NaN
# 34377              218  1965         2  NaN   INC  16728   NaN            NaN
# 34378              218  1965         3  NaN   IND    421   NaN            NaN
#
#       Constituency_Name Constituency_Type  Vote_Share_Percentage  Margin  \
# 0             AKKALKUWA                ST                  41.26    2096
# 1             AKKALKUWA                ST                  40.21   59010
# 2             AKKALKUWA                ST                  10.80   16807
# 7               SHAHADA                ST                  45.12    7991
# 8               SHAHADA                ST                  41.32   65927
# ...                 ...               ...                    ...     ...
# 34374        NAGPUR III                SC                  47.23   19985
# 34375        NAGPUR III                SC                   0.62       0
# 34376           YEOTMAL               GEN                  59.03    8881
# 34377           YEOTMAL               GEN                  38.56   16307
# 34378           YEOTMAL               GEN                   0.97      35
#
#        Margin_Percentage Incumbent
# 0                   1.04      True
# 1                  29.41     False
# 2                   8.38     False
# 7                   3.80     False
# 8                  31.34     False
# ...                  ...       ...
# 34374              46.61     False
# 34375               0.00     False
# 34376              20.47      True
# 34377              37.59     False
# 34378               0.08     False
#
# [11172 rows x 14 columns]

# %%
df2.isna().sum()
# Out:
# Constituency_No             0
# Year                        0
# Position                    0
# Sex                       136
# Party                       1
# Votes                       0
# Age                      7735
# Candidate_Type           7735
# Constituency_Name           0
# Constituency_Type           0
# Vote_Share_Percentage       9
# Margin                      0
# Margin_Percentage           9
# Incumbent                  25
# dtype: int64

# %% [markdown]
# ### Dropping Rows

# %%
df3=df2.dropna(thresh=12)
df3.head()
# Out:
#    Constituency_No  Year  Position Sex Party  Votes   Age Candidate_Type  \
# 0                1  2019         1   M   INC  82770  61.0             ST
# 1                1  2019         2   M   SHS  80674  51.0             ST
# 2                1  2019         3   M   IND  21664  44.0             ST
# 7                2  2019         1   M   BJP  94931  50.0             ST
# 8                2  2019         2   M   INC  86940  51.0             ST
#
#   Constituency_Name Constituency_Type  Vote_Share_Percentage  Margin  \
# 0         AKKALKUWA                ST                  41.26    2096
# 1         AKKALKUWA                ST                  40.21   59010
# 2         AKKALKUWA                ST                  10.80   16807
# 7           SHAHADA                ST                  45.12    7991
# 8           SHAHADA                ST                  41.32   65927
#
#    Margin_Percentage Incumbent
# 0               1.04      True
# 1              29.41     False
# 2               8.38     False
# 7               3.80     False
# 8              31.34     False

# %%
df3.isna().sum()
# Out:
# Constituency_No             0
# Year                        0
# Position                    0
# Sex                         0
# Party                       0
# Votes                       0
# Age                      7594
# Candidate_Type           7594
# Constituency_Name           0
# Constituency_Type           0
# Vote_Share_Percentage       0
# Margin                      0
# Margin_Percentage           0
# Incumbent                   0
# dtype: int64

# %% [markdown]
# ### Filling the Null values in the age column

# %%
#filling null values in the Age column
meanage = round(df3['Age'].mean(), 1) #48.6 #round off to 1 decimal point
df3['Age']=df['Age'].fillna(meanage)
df3
# Out:
# <ipython-input-12-c94a488964de>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Age']=df['Age'].fillna(meanage)
#        Constituency_No  Year  Position Sex Party  Votes   Age Candidate_Type  \
# 0                    1  2019         1   M   INC  82770  61.0             ST
# 1                    1  2019         2   M   SHS  80674  51.0             ST
# 2                    1  2019         3   M   IND  21664  44.0             ST
# 7                    2  2019         1   M   BJP  94931  50.0             ST
# 8                    2  2019         2   M   INC  86940  51.0             ST
# ...                ...   ...       ...  ..   ...    ...   ...            ...
# 34354              263  1962         2   M   PSP   6959  48.6            NaN
# 34355              263  1962         3   M   IND   6259  48.6            NaN
# 34357              264  1962         1   M   INC  26171  48.6            NaN
# 34358              264  1962         2   F   CPI   9191  48.6            NaN
# 34359              264  1962         3   M   PSP   3261  48.6            NaN
#
#       Constituency_Name Constituency_Type  Vote_Share_Percentage  Margin  \
# 0             AKKALKUWA                ST                  41.26    2096
# 1             AKKALKUWA                ST                  40.21   59010
# 2             AKKALKUWA                ST                  10.80   16807
# 7               SHAHADA                ST                  45.12    7991
# 8               SHAHADA                ST                  41.32   65927
# ...                 ...               ...                    ...     ...
# 34354            KANNAD               GEN                  16.98     700
# 34355            KANNAD               GEN                  15.27     425
# 34357            SILLOD               GEN                  67.76   16980
# 34358            SILLOD               GEN                  23.80    5930
# 34359            SILLOD               GEN                   8.44       0
#
#        Margin_Percentage Incumbent
# 0                   1.04      True
# 1                  29.41     False
# 2                   8.38     False
# 7                   3.80     False
# 8                  31.34     False
# ...                  ...       ...
# 34354               1.71     False
# 34355               1.04     False
# 34357              43.96     False
# 34358              15.35     False
# 34359               0.00     False
#
# [11031 rows x 14 columns]

# %%
df3.isna().sum()
# Out:
# Constituency_No             0
# Year                        0
# Position                    0
# Sex                         0
# Party                       0
# Votes                       0
# Age                         0
# Candidate_Type           7594
# Constituency_Name           0
# Constituency_Type           0
# Vote_Share_Percentage       0
# Margin                      0
# Margin_Percentage           0
# Incumbent                   0
# dtype: int64

# %% [markdown]
# ### Filling Missing Values in the Candidate Type Column(Using mode)

# %%
print(df3['Candidate_Type'].unique())
# Out:
# ['ST' 'GEN' 'SC' 'GENERAL' nan]

# %%
#we are performing the following checks to perform the replacement of general to gen
# Standardize values in "Candidate_Type" by stripping whitespace and converting to lowercase
df3['Candidate_Type'] = df3['Candidate_Type'].str.strip().str.lower()

# Replace "general" with "gen" (now that "general" should be standardized)
df3['Candidate_Type'] = df3['Candidate_Type'].replace('general', 'gen')

# Verify the replacement
print(df3['Candidate_Type'].unique())
# Out:
# ['st' 'gen' 'sc' nan]
# <ipython-input-15-7a8d09c1e170>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Candidate_Type'] = df3['Candidate_Type'].str.strip().str.lower()
# <ipython-input-15-7a8d09c1e170>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Candidate_Type'] = df3['Candidate_Type'].replace('general', 'gen')

# %%
#mode for candidate type
mode_candidate=df3['Candidate_Type'].mode()

# %%
df3['Candidate_Type'].fillna(mode_candidate)
df3.tail(10)
# Out:
#        Constituency_No  Year  Position Sex Party  Votes   Age Candidate_Type  \
# 34348              261  1962         3   M   IND   1639  48.6            NaN
# 34350              262  1962         1   F   INC  23830  48.6            NaN
# 34351              262  1962         2   M   PSP  10659  48.6            NaN
# 34352              262  1962         3   M   IND   2093  48.6            NaN
# 34353              263  1962         1   M   INC  21926  48.6            NaN
# 34354              263  1962         2   M   PSP   6959  48.6            NaN
# 34355              263  1962         3   M   IND   6259  48.6            NaN
# 34357              264  1962         1   M   INC  26171  48.6            NaN
# 34358              264  1962         2   F   CPI   9191  48.6            NaN
# 34359              264  1962         3   M   PSP   3261  48.6            NaN
#
#       Constituency_Name Constituency_Type  Vote_Share_Percentage  Margin  \
# 34348          GANGAPUR               GEN                   4.79     247
# 34350          VAIJAPUR               GEN                  65.14   13171
# 34351          VAIJAPUR               GEN                  29.14    8566
# 34352          VAIJAPUR               GEN                   5.72       0
# 34353            KANNAD               GEN                  53.51   14967
# 34354            KANNAD               GEN                  16.98     700
# 34355            KANNAD               GEN                  15.27     425
# 34357            SILLOD               GEN                  67.76   16980
# 34358            SILLOD               GEN                  23.80    5930
# 34359            SILLOD               GEN                   8.44       0
#
#        Margin_Percentage Incumbent
# 34348               0.72     False
# 34350              36.00     False
# 34351              23.42     False
# 34352               0.00     False
# 34353              36.52     False
# 34354               1.71     False
# 34355               1.04     False
# 34357              43.96     False
# 34358              15.35     False
# 34359               0.00     False

# %%
df3.isna().sum()
# Out:
# Constituency_No             0
# Year                        0
# Position                    0
# Sex                         0
# Party                       0
# Votes                       0
# Age                         0
# Candidate_Type           7594
# Constituency_Name           0
# Constituency_Type           0
# Vote_Share_Percentage       0
# Margin                      0
# Margin_Percentage           0
# Incumbent                   0
# dtype: int64

# %%
df3.isna().sum().sum()
# Out:
# 7594

# %% [markdown]
# ### Replacing male as M

# %%
print(df3['Sex'].unique())
# Out:
# ['M' 'F' 'male']

# %%
#we are perofrming the following checks to perform the replacement of general to gen
# Standardize values in "Candidate_Type" by stripping whitespace and converting to lowercase
df3['Sex'] = df3['Sex'].str.strip().str.lower()

# Replace "general" with "gen" (now that "general" should be standardized)
df3['Sex'] = df3['Sex'].replace('male', 'm')

# Verify the replacement
print(df3['Sex'].unique())
# Out:
# ['m' 'f']
# <ipython-input-21-e60d0eef481b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Sex'] = df3['Sex'].str.strip().str.lower()
# <ipython-input-21-e60d0eef481b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Sex'] = df3['Sex'].replace('male', 'm')

# %% [markdown]
# ### downloading the dataset as a csv file

# %%
#downloading the dataset as a csv file
final=df3.to_csv('preprocessed_election.csv', index=False)
